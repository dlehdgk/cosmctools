# %% [markdown]
# Notebook on using `cosmotools` to extract parameter constraints using `getdist`, getting $\chi^2$, getting $\ln\mathcal{Z}$ estimates using `MCEvidence` and `harmonic`

# %%
from cosmctools import *
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl

mpl.rcParams["figure.dpi"] = 300
mpl.rc("axes", labelsize=16)
mpl.rc("legend", fontsize=14)
mpl.rc("xtick", labelsize=12)
mpl.rc("ytick", labelsize=12)

# %%
def make_and_train(root, params, burnin, block_num, temp=0.8):
    m = cosmo_model(root, burnin=burnin, block_num=block_num)
    m.set_sampled_params(params)
    m.train_model(verbose=False, store_model=False)
    m.set_temp(temp=temp)
    return m

# %% [markdown]
# # Comparing the effects of parameter choices on evidences
#
# looking at the sampled parameters in MCMC samples, can catagorise into:
#
# 1) constrained cosmological parameters
#
# 2) unconstrained cosmological parameters (prior dominated)
#
# 3) nuisance parameters (can be also prior dominated)
#
# ## Plan
#
# - get evidence for the following set of parameters:
#
#     - all sampled parameters
#
#     - excluding nuisance parameters (cosmological parameters only)
#
#     - excluding the prior dominated parameters (keep constrained cosmological parameters and nuisance parameters)
#
#     - only constrained cosmological parameters
#
# - check both Bayesian evidence and Bayes factor to see if there are variations
#
# - the values from papers are not exact one to one comparisons given that they use a different set of parameters with different prior ranges

# %% [markdown]
# # CMB+BAO+SNe

# %%
# including or excluding nuisance parameters (CMB+BAO+SNe)

## parameters
lcdm_cosmo_params = [
    "theta_s_100",
    "omega_b",
    "omega_cdm",
    "logA",
    "n_s",
    "tau_reio;0.9999995",
]
nuisance_params = ["A_planck", "P_act", "Tcal;0.9999995", "Ecal"]
cpl_cosmo_params = lcdm_cosmo_params + ["w0_fld", "wa_fld"]

## initialising objects
lcdm_cosmo_only = cosmo_model("../lcdm_chains/ts_CMB-SPA+DD+DESI", block_num=12)
lcdm_full = cosmo_model("../lcdm_chains/ts_CMB-SPA+DD+DESI", block_num=12)
cpl_cosmo_only = cosmo_model(
    "../cpl_chains/ts_CMB-SPA+DD+DESI", block_num=12, burnin=0.5
)
cpl_full = cosmo_model("../cpl_chains/ts_CMB-SPA+DD+DESI", block_num=12, burnin=0.5)

## setting parameters
lcdm_cosmo_only.set_sampled_params(lcdm_cosmo_params)
lcdm_full.set_sampled_params(lcdm_cosmo_params + nuisance_params)
cpl_cosmo_only.set_sampled_params(cpl_cosmo_params)
cpl_full.set_sampled_params(cpl_cosmo_params + nuisance_params)

## check convergence on chains such so that correct burnin has been removed
print(f"LCDM R-1 = {lcdm_cosmo_only.get_gelman_rubin()}")
print(f"CPL R-1 = {cpl_cosmo_only.get_gelman_rubin()}")
# Out:
# ../lcdm_chains/ts_CMB-SPA+DD+DESI.1.txt
# ../lcdm_chains/ts_CMB-SPA+DD+DESI.2.txt
# ../lcdm_chains/ts_CMB-SPA+DD+DESI.3.txt
# ../lcdm_chains/ts_CMB-SPA+DD+DESI.4.txt
# Removed 0.3 as burn in
# LCDM R-1 = 0.00819280250382877
# ../cpl_chains/ts_CMB-SPA+DD+DESI.1.txt
# ../cpl_chains/ts_CMB-SPA+DD+DESI.2.txt
# ../cpl_chains/ts_CMB-SPA+DD+DESI.3.txt
# ../cpl_chains/ts_CMB-SPA+DD+DESI.4.txt
# Removed 0.5 as burn in
# CPL R-1 = 0.009385908497231667

# %%
# training normalising flows for each object
lcdm_cosmo_only.train_model(verbose=True, temp=0.8)
lcdm_full.train_model(verbose=True, temp=0.8)
cpl_cosmo_only.train_model(verbose=True, temp=0.8)
cpl_full.train_model(verbose=True, temp=0.8)
# Out:
# W0522 18:05:07.201872 4853875 cpp_gen_intrinsics.cc:74] Empty bitcode string provided for eigen. Optimizations relying on this IR will be disabled.
# Training NF: 100%|██████████| 15/15 [00:28<00:00,  1.88s/it]
# ensure that the concentrated flow is contained within the posterior
# Training NF: 100%|██████████| 15/15 [00:38<00:00,  2.55s/it]
# ensure that the concentrated flow is contained within the posterior
# Training NF: 100%|██████████| 15/15 [01:05<00:00,  4.34s/it]
# ensure that the concentrated flow is contained within the posterior
# Training NF: 100%|██████████| 15/15 [01:20<00:00,  5.39s/it]
# ensure that the concentrated flow is contained within the posterior

# %%
# adjusting the temperatures of the trained flows to ensure that the trained distribution is contained within the posterior. Default from above is $0.9$,

# lcdm_cosmo_only.set_temp(temp=0.7, verbose=True)
# lcdm_full.set_temp(temp=0.7, verbose=True)
cpl_cosmo_only.set_temp(temp=0.7, verbose=True)
cpl_full.set_temp(temp=0.7, verbose=True)
# Out:
# ensure that the concentrated flow is contained within the posterior
# ensure that the concentrated flow is contained within the posterior

# %%
# MCEvidence evidence and Bayes factor

mce_cosmo_only = lcdm_cosmo_only.get_MCE_bayes_factor(cpl_cosmo_only)
mce_full = lcdm_full.get_MCE_bayes_factor(cpl_full)
# Out:
# ...
# RUNNING MCMC EVIDENCE FOR COBAYA
# ...
# INFO:MCEvidence.py.params_info():1377     getting params info from COSMOMC file ../lcdm_chains/ts_CMB-SPA+DD+DESI_BE.ranges
# INFO:MCEvidence.py.get_prior_volume():1486     getting prior volume using cosmomc *.ranges or montepython log.param outputs
# INFO:MCEvidence.py.get_prior_volume():1489     prior_volume=0.04952928869697333
# INFO:MCEvidence.py.get_prior_volume():1490     Number of params to use: ndim=6
# INFO:MCEvidence.py.setup():164      Loading chain from ../lcdm_chains/ts_CMB-SPA+DD+DESI_BE
# INFO:MCEvidence.py.load_from_file():666       loading files: ../lcdm_chains/ts_CMB-SPA+DD+DESI_BE.?.txt
# INFO:MCEvidence.py.read_list_to_array():635      loading: ../lcdm_chains/ts_CMB-SPA+DD+DESI_BE.4.txt
# INFO:MCEvidence.py.read_list_to_array():635      loading: ../lcdm_chains/ts_CMB-SPA+DD+DESI_BE.2.txt
# INFO:MCEvidence.py.read_list_to_array():635      loading: ../lcdm_chains/ts_CMB-SPA+DD+DESI_BE.3.txt
# ...

# %%
# harmonic evidence and Bayes factor

harm_cosmo_only = lcdm_cosmo_only.get_LHME_bayes_factor(cpl_cosmo_only)
harm_full = lcdm_full.get_LHME_bayes_factor(cpl_full)

print("LCDM cosmological parameters only block num=12")
lcdm_cosmo_only.check_evidence()
print("CPL cosmological parameters only block num=12")
cpl_cosmo_only.check_evidence()
print("LCDM cosmological + nuisance parameters block num=12")
lcdm_full.check_evidence()
print("CPL cosmological + nuisance parameters block num=12")
cpl_full.check_evidence()
# Out:
# LCDM cosmological parameters only block num=12
# === Checking Reliability of Evidence ===
# ln kurtosis: 1.3162 (>>1 implies evidence may be unreliable)
# CPL cosmological parameters only block num=12
# === Checking Reliability of Evidence ===
# ln kurtosis: 0.4413 (>>1 implies evidence may be unreliable)
# LCDM cosmological + nuisance parameters block num=12
# === Checking Reliability of Evidence ===
# ln kurtosis: 0.8771 (>>1 implies evidence may be unreliable)
# CPL cosmological + nuisance parameters block num=12
# === Checking Reliability of Evidence ===
# ln kurtosis: 1.1136 (>>1 implies evidence may be unreliable)

# %%
# block_num variants for harmonic (CMB+BAO+SNe) — fully reinitialise and retrain

block_nums = [8, 12, 24]

# results at the original block_num=12 (already computed above)
harm_cosmo_only_blocks = {12: harm_cosmo_only}
harm_full_blocks = {12: harm_full}
hmZ_lcdm_cosmo = {12: lcdm_cosmo_only.get_hm_evidence()}
hmZ_cpl_cosmo = {12: cpl_cosmo_only.get_hm_evidence()}
hmZ_lcdm_full = {12: lcdm_full.get_hm_evidence()}
hmZ_cpl_full = {12: cpl_full.get_hm_evidence()}

lcdm_root = "../lcdm_chains/ts_CMB-SPA+DD+DESI"
cpl_root = "../cpl_chains/ts_CMB-SPA+DD+DESI"

for bn in [8, 24]:
    # cosmo-only
    a = make_and_train(lcdm_root, lcdm_cosmo_params, burnin=0.3, block_num=bn)
    b = make_and_train(cpl_root, cpl_cosmo_params, burnin=0.5, block_num=bn, temp=0.7)
    harm_cosmo_only_blocks[bn] = a.get_LHME_bayes_factor(b)
    hmZ_lcdm_cosmo[bn] = a.get_hm_evidence()
    hmZ_cpl_cosmo[bn] = b.get_hm_evidence()
    print(f"LCDM cosmological parameters only block num={bn}")
    a.check_evidence()
    print(f"CPL cosmological parameters only block num={bn}")
    b.check_evidence()

    # cosmo + nuisance
    a = make_and_train(
        lcdm_root, lcdm_cosmo_params + nuisance_params, burnin=0.3, block_num=bn
    )
    b = make_and_train(
        cpl_root, cpl_cosmo_params + nuisance_params, burnin=0.5, block_num=bn, temp=0.7
    )
    harm_full_blocks[bn] = a.get_LHME_bayes_factor(b)
    hmZ_lcdm_full[bn] = a.get_hm_evidence()
    hmZ_cpl_full[bn] = b.get_hm_evidence()
    print(f"LCDM cosmological + nuisance parameters block num={bn}")
    a.check_evidence()
    print(f"CPL cosmological + nuisance parameters block num={bn}")
    b.check_evidence()
# Out:
# LCDM cosmological parameters only block num=8
# === Checking Reliability of Evidence ===
# ln kurtosis: 0.7814 (>>1 implies evidence may be unreliable)
# CPL cosmological parameters only block num=8
# === Checking Reliability of Evidence ===
# ln kurtosis: 0.4281 (>>1 implies evidence may be unreliable)
# LCDM cosmological + nuisance parameters block num=8
# === Checking Reliability of Evidence ===
# ln kurtosis: 0.7234 (>>1 implies evidence may be unreliable)
# CPL cosmological + nuisance parameters block num=8
# === Checking Reliability of Evidence ===
# ln kurtosis: 0.7488 (>>1 implies evidence may be unreliable)
# LCDM cosmological parameters only block num=24
# === Checking Reliability of Evidence ===
# ln kurtosis: 1.0064 (>>1 implies evidence may be unreliable)
# CPL cosmological parameters only block num=24
# === Checking Reliability of Evidence ===
# ln kurtosis: 0.7560 (>>1 implies evidence may be unreliable)
# LCDM cosmological + nuisance parameters block num=24
# ...

# %%
# plotting Bayes factor and individual evidences (CMB+BAO+SNe)
x_labels = ["Cosmo", "Cosmo + Nuisance"]
x_pos = np.array([0, 1])
block_offsets = {8: -0.18, 12: 0.0, 24: 0.18}
block_colors = {8: "tab:cyan", 12: "blue", 24: "navy"}

fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# --- Bayes factor ---
ax = axes[0]
ax.axhline(1.7, color="black", linestyle=":", label="Nautilus")
for bn in block_nums:
    means = [harm_cosmo_only_blocks[bn][0], harm_full_blocks[bn][0]]
    lower = [harm_cosmo_only_blocks[bn][1], harm_full_blocks[bn][1]]
    upper = [harm_cosmo_only_blocks[bn][2], harm_full_blocks[bn][2]]
    ax.errorbar(
        x_pos + block_offsets[bn],
        means,
        yerr=[lower, upper],
        fmt="o",
        color=block_colors[bn],
        capsize=5,
        label=f"LHME ({bn})",
        markersize=7,
    )
ax.plot(x_pos, [mce_cosmo_only, mce_full], "s", color="red", label="MCE", markersize=9)
ax.set_xticks(x_pos)
ax.set_xticklabels(x_labels)
ax.set_ylabel(r"$\ln\mathcal{Z}_\mathrm{CPL}-\ln\mathcal{Z}_{\Lambda\mathrm{CDM}}$")
ax.set_title("Bayes factor")
ax.set_xlim(-1, 2)
ax.legend(fontsize=8)
ax.grid(axis="y", linestyle="--", alpha=0.7)

# --- Individual evidences ---
ax = axes[1]
ax.axhline(
    -1155.6, color="black", linestyle=":", label="$\\Lambda\\mathrm{CDM}$: Nautilus"
)
ax.axhline(-1153.9, color="black", linestyle="-.", label="CPL: Nautilus")
for bn in block_nums:
    lcdm_co_lnZ, (lcdm_co_lo, lcdm_co_up) = hmZ_lcdm_cosmo[bn]
    cpl_co_lnZ, (cpl_co_lo, cpl_co_up) = hmZ_cpl_cosmo[bn]
    lcdm_fu_lnZ, (lcdm_fu_lo, lcdm_fu_up) = hmZ_lcdm_full[bn]
    cpl_fu_lnZ, (cpl_fu_lo, cpl_fu_up) = hmZ_cpl_full[bn]
    ax.errorbar(
        x_pos + block_offsets[bn] - 0.05,
        [lcdm_co_lnZ, lcdm_fu_lnZ],
        yerr=[[lcdm_co_lo, lcdm_fu_lo], [lcdm_co_up, lcdm_fu_up]],
        fmt="o",
        color=block_colors[bn],
        capsize=5,
        label=f"$\\Lambda\\mathrm{{CDM}}$: LHME({bn})",
        markersize=7,
    )
    ax.errorbar(
        x_pos + block_offsets[bn] + 0.05,
        [cpl_co_lnZ, cpl_fu_lnZ],
        yerr=[[cpl_co_lo, cpl_fu_lo], [cpl_co_up, cpl_fu_up]],
        fmt="^",
        color=block_colors[bn],
        capsize=5,
        label=f"CPL: LHME({bn})",
        markersize=7,
    )

ax.plot(
    x_pos - 0.05,
    [lcdm_cosmo_only.mcevidence, lcdm_full.mcevidence],
    "o",
    color="red",
    label="$\\Lambda\\mathrm{CDM}$: MCE",
    markersize=9,
)
ax.plot(
    x_pos + 0.05,
    [cpl_cosmo_only.mcevidence, cpl_full.mcevidence],
    "^",
    color="red",
    label="CPL: MCE",
    markersize=9,
)

ax.set_xticks(x_pos)
ax.set_xticklabels(x_labels)
ax.set_ylabel(r"$\ln\mathcal{Z}$")
ax.set_title("Bayesian evidence")
ax.set_xlim(-1, 2)
ax.legend(fontsize=7)
ax.grid(axis="y", linestyle="--", alpha=0.7)

fig.suptitle("CMB-SPA + DESI DR2 + DES Y5 (Dovekie)")
plt.tight_layout()
plt.savefig("figures/CMB_DD_DESI_evidence.pdf", bbox_inches="tight")
plt.show()
# Out:
# INFO:_mathtext.py._get_glyph():642      Substituting symbol Z from STIXNonUnicode
# INFO:_mathtext.py._get_glyph():642      Substituting symbol Z from STIXNonUnicode
# INFO:_mathtext.py._get_glyph():642      Substituting symbol Z from STIXNonUnicode
# INFO:_mathtext.py._get_glyph():642      Substituting symbol Z from STIXNonUnicode
# INFO:_mathtext.py._get_glyph():642      Substituting symbol Z from STIXNonUnicode
# INFO:_mathtext.py._get_glyph():642      Substituting symbol Z from STIXNonUnicode
# INFO:_mathtext.py._get_glyph():642      Substituting symbol Z from STIXNonUnicode
# INFO:_mathtext.py._get_glyph():642      Substituting symbol Z from STIXNonUnicode

# %% [markdown]
# # BAO+SNe

# %%
# including or excluding unconstrained parameters (BAO+SNe)

## parameters
lcdm_cosmo_params = [
    "H0",
    "omega_b",
    "omega_cdm",
]
prior_params = ["logA", "n_s"]
cpl_cosmo_params = lcdm_cosmo_params + ["w0_fld", "wa_fld"]

## initialising objects
lcdm_const_only = cosmo_model("../lcdm_chains/DD+DESI", block_num=12, burnin=0.5)
lcdm_all = cosmo_model("../lcdm_chains/DD+DESI", block_num=12, burnin=0.5)
cpl_const_only = cosmo_model("../cpl_chains/DD+DESI", block_num=12, burnin=0.5)
cpl_all = cosmo_model("../cpl_chains/DD+DESI", block_num=12, burnin=0.5)

## setting parameters
lcdm_const_only.set_sampled_params(lcdm_cosmo_params)
lcdm_all.set_sampled_params(lcdm_cosmo_params + prior_params)
cpl_const_only.set_sampled_params(cpl_cosmo_params)
cpl_all.set_sampled_params(cpl_cosmo_params + prior_params)

## check convergence on chains such so that correct burnin has been removed
print(f"LCDM R-1 = {lcdm_const_only.get_gelman_rubin()}")
print(f"CPL R-1 = {cpl_const_only.get_gelman_rubin()}")
# Out:
# WARNING:mcsamples.py.updateBaseStatistics():562      outlier fraction 0.00010301844030081384
# LCDM R-1 = 0.009448838358317401
# CPL R-1 = 0.004381148188664222

# %%
# training normalising flows for each BAO+SNe object
lcdm_const_only.train_model(verbose=True, temp=0.8)
lcdm_all.train_model(verbose=True, temp=0.8)
cpl_const_only.train_model(verbose=True, temp=0.8)
cpl_all.train_model(verbose=True, temp=0.8)
# Out:
# Training NF: 100%|██████████| 15/15 [00:16<00:00,  1.13s/it]
# ensure that the concentrated flow is contained within the posterior
# Training NF: 100%|██████████| 15/15 [00:19<00:00,  1.32s/it]
# ensure that the concentrated flow is contained within the posterior
# Training NF: 100%|██████████| 15/15 [02:15<00:00,  9.06s/it]
# ensure that the concentrated flow is contained within the posterior
# Training NF: 100%|██████████| 15/15 [02:45<00:00, 11.03s/it]
# ensure that the concentrated flow is contained within the posterior

# %%
# adjust temperature of the trained flows for BAO+SNe
lcdm_const_only.set_temp(temp=0.7, verbose=True)
lcdm_all.set_temp(temp=0.7, verbose=True)
# cpl_const_only.set_temp(temp=0.7, verbose=True)
# cpl_all.set_temp(temp=0.7, verbose=True)
# Out:
# ensure that the concentrated flow is contained within the posterior
# ensure that the concentrated flow is contained within the posterior

# %%
# MCEvidence evidence and Bayes factor (BAO+SNe)
mce_const_only = lcdm_const_only.get_MCE_bayes_factor(cpl_const_only)
mce_all = lcdm_all.get_MCE_bayes_factor(cpl_all)
# Out:
# ...
# RUNNING MCMC EVIDENCE FOR COBAYA
# ...
# INFO:MCEvidence.py.params_info():1377     getting params info from COSMOMC file ../lcdm_chains/DD+DESI_BE.ranges
# INFO:MCEvidence.py.get_prior_volume():1486     getting prior volume using cosmomc *.ranges or montepython log.param outputs
# INFO:MCEvidence.py.get_prior_volume():1489     prior_volume=5.6373
# INFO:MCEvidence.py.get_prior_volume():1490     Number of params to use: ndim=3
# INFO:MCEvidence.py.setup():164      Loading chain from ../lcdm_chains/DD+DESI_BE
# INFO:MCEvidence.py.load_from_file():666       loading files: ../lcdm_chains/DD+DESI_BE.?.txt
# INFO:MCEvidence.py.read_list_to_array():635      loading: ../lcdm_chains/DD+DESI_BE.4.txt
# INFO:MCEvidence.py.read_list_to_array():635      loading: ../lcdm_chains/DD+DESI_BE.2.txt
# INFO:MCEvidence.py.read_list_to_array():635      loading: ../lcdm_chains/DD+DESI_BE.3.txt
# INFO:MCEvidence.py.read_list_to_array():635      loading: ../lcdm_chains/DD+DESI_BE.1.txt
# ...

# %%
# harmonic evidence and Bayes factor (BAO+SNe)
harm_const_only = lcdm_const_only.get_LHME_bayes_factor(cpl_const_only)
harm_all = lcdm_all.get_LHME_bayes_factor(cpl_all)

print("LCDM constrained parameters only block num=12")
lcdm_const_only.check_evidence()
print("CPL constrained parameters only block num=12")
cpl_const_only.check_evidence()
print("LCDM all sampled parameters block num=12")
lcdm_all.check_evidence()
print("CPL all sampled parameters block num=12")
cpl_all.check_evidence()
# Out:
# LCDM constrained parameters only block num=12
# === Checking Reliability of Evidence ===
# ln kurtosis: 1.2807 (>>1 implies evidence may be unreliable)
# CPL constrained parameters only block num=12
# === Checking Reliability of Evidence ===
# ln kurtosis: 0.4089 (>>1 implies evidence may be unreliable)
# LCDM all sampled parameters block num=12
# === Checking Reliability of Evidence ===
# ln kurtosis: 1.2800 (>>1 implies evidence may be unreliable)
# CPL all sampled parameters block num=12
# === Checking Reliability of Evidence ===
# ln kurtosis: 0.5488 (>>1 implies evidence may be unreliable)

# %%
# block_num variants for harmonic (BAO+SNe) — fully reinitialise and retrain
harm_const_only_blocks = {12: harm_const_only}
harm_all_blocks = {12: harm_all}
hmZ_lcdm_const = {12: lcdm_const_only.get_hm_evidence()}
hmZ_cpl_const = {12: cpl_const_only.get_hm_evidence()}
hmZ_lcdm_all = {12: lcdm_all.get_hm_evidence()}
hmZ_cpl_all = {12: cpl_all.get_hm_evidence()}

lcdm_root_bs = "../lcdm_chains/DD+DESI"
cpl_root_bs = "../cpl_chains/DD+DESI"

for bn in [8, 24]:
    # constrained-only
    a = make_and_train(
        lcdm_root_bs, lcdm_cosmo_params, burnin=0.5, block_num=bn, temp=0.7
    )
    b = make_and_train(cpl_root_bs, cpl_cosmo_params, burnin=0.5, block_num=bn)
    harm_const_only_blocks[bn] = a.get_LHME_bayes_factor(b)
    hmZ_lcdm_const[bn] = a.get_hm_evidence()
    hmZ_cpl_const[bn] = b.get_hm_evidence()
    print(f"LCDM constrained parameters only block num={bn}")
    a.check_evidence()
    print(f"CPL constrained parameters only block num={bn}")
    b.check_evidence()

    # constrained + prior-dominated
    a = make_and_train(
        lcdm_root_bs,
        lcdm_cosmo_params + prior_params,
        burnin=0.5,
        block_num=bn,
        temp=0.7,
    )
    b = make_and_train(
        cpl_root_bs, cpl_cosmo_params + prior_params, burnin=0.5, block_num=bn
    )
    harm_all_blocks[bn] = a.get_LHME_bayes_factor(b)
    hmZ_lcdm_all[bn] = a.get_hm_evidence()
    hmZ_cpl_all[bn] = b.get_hm_evidence()
    print(f"LCDM all sampled parameters block num={bn}")
    a.check_evidence()
    print(f"CPL all sampled parameters block num={bn}")
    b.check_evidence()
# Out:
# LCDM constrained parameters only block num=8
# === Checking Reliability of Evidence ===
# ln kurtosis: 0.8010 (>>1 implies evidence may be unreliable)
# CPL constrained parameters only block num=8
# === Checking Reliability of Evidence ===
# ln kurtosis: 0.4923 (>>1 implies evidence may be unreliable)
# LCDM all sampled parameters block num=8
# === Checking Reliability of Evidence ===
# ln kurtosis: 0.6407 (>>1 implies evidence may be unreliable)
# CPL all sampled parameters block num=8
# === Checking Reliability of Evidence ===
# ln kurtosis: 0.3089 (>>1 implies evidence may be unreliable)
# LCDM constrained parameters only block num=24
# === Checking Reliability of Evidence ===
# ln kurtosis: 0.9715 (>>1 implies evidence may be unreliable)
# CPL constrained parameters only block num=24
# === Checking Reliability of Evidence ===
# ln kurtosis: 0.9180 (>>1 implies evidence may be unreliable)
# LCDM all sampled parameters block num=24
# === Checking Reliability of Evidence ===
# ...

# %%
# plotting Bayes factor and individual evidences (BAO+SNe)
x_labels_bs = ["Constrained Only", "All parameters"]
x_pos_bs = np.array([0, 1])

fig, axes = plt.subplots(1, 2, figsize=(14, 6))

block_nums = [8, 12, 24]
block_offsets = {8: -0.18, 12: 0.0, 24: 0.18}
block_colors = {8: "tab:cyan", 12: "blue", 24: "navy"}
# --- Bayes factor ---
ax = axes[0]
ax.axhline(-1.1, color="black", linestyle="-.", label="Nautilus")
ax.axhline(-1.63, color="grey", linestyle="-", label="polyChord")
ax.axhspan(-1.63 - 0.12, -1.63 + 0.12, color="green", alpha=0.15)
ax.plot(
    x_pos_bs, [mce_const_only, mce_all], "s", color="red", label="MCE", markersize=9
)
for bn in block_nums:
    means = [harm_const_only_blocks[bn][0], harm_all_blocks[bn][0]]
    lower = [harm_const_only_blocks[bn][1], harm_all_blocks[bn][1]]
    upper = [harm_const_only_blocks[bn][2], harm_all_blocks[bn][2]]
    ax.errorbar(
        x_pos_bs + block_offsets[bn],
        means,
        yerr=[lower, upper],
        fmt="o",
        color=block_colors[bn],
        capsize=5,
        label=f"LHME ({bn})",
        markersize=7,
    )
ax.set_xticks(x_pos_bs)
ax.set_xticklabels(x_labels_bs)
ax.set_ylabel(r"$\ln\mathcal{Z}_\mathrm{CPL}-\ln\mathcal{Z}_{\Lambda\mathrm{CDM}}$")
ax.set_title("Bayes factor")
ax.set_xlim(-1, 2)
ax.legend(fontsize=8)
ax.grid(axis="y", linestyle="--", alpha=0.7)

# --- Individual evidences ---
ax = axes[1]
# Nautilus from DES:2025sig
ax.axhline(
    -833.2, color="darkgreen", linestyle=":", label="$\\Lambda\\mathrm{CDM}$: Nautilus"
)
ax.axhline(
    -834.3, color="darkred", linestyle="-.", label="$\\Lambda\\mathrm{CPL}$: Nautilus"
)
# PolyChord from Ong:2026tta
ax.axhline(
    -831.84,
    color="darkgreen",
    linestyle="-",
    label="$\\Lambda\\mathrm{CDM}$: polyChord",
)
ax.axhspan(-831.84 - 0.1, -831.84 + 0.1, color="green", alpha=0.15)

ax.axhline(-833.46, color="darkred", linestyle="-", label="CPL: polyChord")
ax.axhspan(-833.46 - 0.12, -833.46 + 0.12, color="red", alpha=0.15)

for bn in block_nums:
    lcdm_co_lnZ, (lcdm_co_lo, lcdm_co_up) = hmZ_lcdm_const[bn]
    cpl_co_lnZ, (cpl_co_lo, cpl_co_up) = hmZ_cpl_const[bn]
    lcdm_al_lnZ, (lcdm_al_lo, lcdm_al_up) = hmZ_lcdm_all[bn]
    cpl_al_lnZ, (cpl_al_lo, cpl_al_up) = hmZ_cpl_all[bn]
    ax.errorbar(
        x_pos_bs + block_offsets[bn] - 0.05,
        [lcdm_co_lnZ, lcdm_al_lnZ],
        yerr=[[lcdm_co_lo, lcdm_al_lo], [lcdm_co_up, lcdm_al_up]],
        fmt="o",
        color=block_colors[bn],
        capsize=5,
        label=f"$\\Lambda\\mathrm{{CDM}}$: LHME({bn})",
        markersize=7,
    )
    ax.errorbar(
        x_pos_bs + block_offsets[bn] + 0.05,
        [cpl_co_lnZ, cpl_al_lnZ],
        yerr=[[cpl_co_lo, cpl_al_lo], [cpl_co_up, cpl_al_up]],
        fmt="^",
        color=block_colors[bn],
        capsize=5,
        label=f"CPL: LHME({bn})",
        markersize=7,
    )

ax.plot(
    x_pos_bs - 0.05,
    [lcdm_const_only.mcevidence, lcdm_all.mcevidence],
    "o",
    color="red",
    label="$\\Lambda\\mathrm{{CDM}}$: MCE",
    markersize=9,
)
ax.plot(
    x_pos_bs + 0.05,
    [cpl_const_only.mcevidence, cpl_all.mcevidence],
    "^",
    color="red",
    label="CPL: MCE",
    markersize=9,
)
ax.set_xticks(x_pos_bs)
ax.set_xticklabels(x_labels_bs)
ax.set_ylabel(r"$\ln\mathcal{Z}$")
ax.set_title("Bayesian evidence")
ax.set_xlim(-1, 2)
ax.legend(fontsize=7)
ax.grid(axis="y", linestyle="--", alpha=0.7)

fig.suptitle("DESI DR2 + DES Y5 (Dovekie)")
plt.tight_layout()
plt.savefig("figures/DD_DESI_evidence.pdf", bbox_inches="tight")
plt.show()
# Out:
# INFO:_mathtext.py._get_glyph():642      Substituting symbol Z from STIXNonUnicode
# INFO:_mathtext.py._get_glyph():642      Substituting symbol Z from STIXNonUnicode
# INFO:_mathtext.py._get_glyph():642      Substituting symbol Z from STIXNonUnicode
# INFO:_mathtext.py._get_glyph():642      Substituting symbol Z from STIXNonUnicode
# INFO:_mathtext.py._get_glyph():642      Substituting symbol Z from STIXNonUnicode
# INFO:_mathtext.py._get_glyph():642      Substituting symbol Z from STIXNonUnicode
# INFO:_mathtext.py._get_glyph():642      Substituting symbol Z from STIXNonUnicode
# INFO:_mathtext.py._get_glyph():642      Substituting symbol Z from STIXNonUnicode

# %%
fig, ax = plt.subplots()
# --- Bayes factor ---
ax.axhline(-1.1, color="black", linestyle="-.", label="Nautilus")
ax.axhline(-1.63, color="grey", linestyle="-", label="polyChord")
ax.axhspan(-1.63 - 0.12, -1.63 + 0.12, color="green", alpha=0.15)
ax.plot(
    x_pos_bs, [mce_const_only, mce_all], "s", color="red", label="MCE", markersize=9
)
for bn in block_nums:
    means = [harm_const_only_blocks[bn][0], harm_all_blocks[bn][0]]
    lower = [harm_const_only_blocks[bn][1], harm_all_blocks[bn][1]]
    upper = [harm_const_only_blocks[bn][2], harm_all_blocks[bn][2]]
    ax.errorbar(
        x_pos_bs + block_offsets[bn],
        means,
        yerr=[lower, upper],
        fmt="o",
        color=block_colors[bn],
        capsize=5,
        label=f"LHME ({bn})",
        markersize=7,
    )
ax.set_xticks(x_pos_bs)
ax.set_xticklabels(x_labels_bs)
ax.set_ylabel(r"$\ln\mathcal{Z}_\mathrm{CPL}-\ln\mathcal{Z}_{\Lambda\mathrm{CDM}}$")
# ax.set_title("Bayes factor")
ax.set_xlim(-1, 2)
ax.legend(fontsize=8)
ax.grid(axis="y", linestyle="--", alpha=0.7)


plt.savefig("figures/DD_DESI_bf.pdf", bbox_inches="tight")
plt.show()
# Out:
# INFO:_mathtext.py._get_glyph():642      Substituting symbol Z from STIXNonUnicode
# INFO:_mathtext.py._get_glyph():642      Substituting symbol Z from STIXNonUnicode
# INFO:_mathtext.py._get_glyph():642      Substituting symbol Z from STIXNonUnicode
# INFO:_mathtext.py._get_glyph():642      Substituting symbol Z from STIXNonUnicode

# %%
# including or excluding unconstrained parameters (BAO+SNe)

## parameters
lcdm_cosmo_params = [
    "H0",
    "omega_b",
    "omega_cdm",
]
prior_params = ["logA", "n_s"]
cpl_cosmo_params = lcdm_cosmo_params + ["w0_fld", "wa_fld"]

## initialising objects
lcdm_const_only_pp = cosmo_model("../lcdm_chains/PP+DESI", block_num=12)
lcdm_all_pp = cosmo_model("../lcdm_chains/PP+DESI", block_num=12)
cpl_const_only_pp = cosmo_model("../cpl_chains/PP+DESI", block_num=12)
cpl_all_pp = cosmo_model("../cpl_chains/PP+DESI", block_num=12)

## setting parameters
lcdm_const_only_pp.set_sampled_params(lcdm_cosmo_params)
lcdm_all_pp.set_sampled_params(lcdm_cosmo_params + prior_params)
cpl_const_only_pp.set_sampled_params(cpl_cosmo_params)
cpl_all_pp.set_sampled_params(cpl_cosmo_params + prior_params)

## check convergence on chains such so that correct burnin has been removed
print(f"LCDM R-1 = {lcdm_const_only_pp.get_gelman_rubin()}")
print(f"CPL R-1 = {cpl_const_only_pp.get_gelman_rubin()}")
# Out:
# LCDM R-1 = 0.0092007390452724
# CPL R-1 = 0.004872546848462032

# %%
# training normalising flows for each BAO+SNe object
lcdm_const_only_pp.train_model(temp=0.8, verbose=True)
lcdm_all_pp.train_model(temp=0.8, verbose=True)
cpl_const_only_pp.train_model(temp=0.8, verbose=True)
cpl_all_pp.train_model(temp=0.8, verbose=True)
# Out:
# Training NF: 100%|██████████| 15/15 [00:42<00:00,  2.85s/it]
# ensure that the concentrated flow is contained within the posterior
# Training NF: 100%|██████████| 15/15 [00:49<00:00,  3.33s/it]
# ensure that the concentrated flow is contained within the posterior
# Training NF: 100%|██████████| 15/15 [01:53<00:00,  7.54s/it]
# ensure that the concentrated flow is contained within the posterior
# Training NF: 100%|██████████| 15/15 [02:17<00:00,  9.14s/it]
# ensure that the concentrated flow is contained within the posterior

# %%
# adjust temperature of the trained flows for BAO+SNe
# lcdm_const_only_pp.set_temp(temp=0.7, verbose=True)
# lcdm_all_pp.set_temp(temp=0.7, verbose=True)
# cpl_const_only_pp.set_temp(temp=0.7, verbose=True)
# cpl_all_pp.set_temp(temp=0.7, verbose=True)

# %%
# MCEvidence evidence and Bayes factor (BAO+SNe)
mce_const_only_pp = lcdm_const_only_pp.get_MCE_bayes_factor(cpl_const_only_pp)
mce_all_pp = lcdm_all_pp.get_MCE_bayes_factor(cpl_all_pp)
# Out:
# ...
# RUNNING MCMC EVIDENCE FOR COBAYA
# ...
# INFO:MCEvidence.py.params_info():1377     getting params info from COSMOMC file ../lcdm_chains/PP+DESI_BE.ranges
# INFO:MCEvidence.py.get_prior_volume():1486     getting prior volume using cosmomc *.ranges or montepython log.param outputs
# INFO:MCEvidence.py.get_prior_volume():1489     prior_volume=5.6373
# INFO:MCEvidence.py.get_prior_volume():1490     Number of params to use: ndim=3
# INFO:MCEvidence.py.setup():164      Loading chain from ../lcdm_chains/PP+DESI_BE
# INFO:MCEvidence.py.load_from_file():666       loading files: ../lcdm_chains/PP+DESI_BE.?.txt
# INFO:MCEvidence.py.read_list_to_array():635      loading: ../lcdm_chains/PP+DESI_BE.4.txt
# INFO:MCEvidence.py.read_list_to_array():635      loading: ../lcdm_chains/PP+DESI_BE.2.txt
# INFO:MCEvidence.py.read_list_to_array():635      loading: ../lcdm_chains/PP+DESI_BE.3.txt
# INFO:MCEvidence.py.read_list_to_array():635      loading: ../lcdm_chains/PP+DESI_BE.1.txt
# ...

# %%
# harmonic evidence and Bayes factor (BAO+SNe)
harm_const_only_pp = lcdm_const_only_pp.get_LHME_bayes_factor(cpl_const_only_pp)
harm_all_pp = lcdm_all_pp.get_LHME_bayes_factor(cpl_all_pp)

print("LCDM constrained parameters only block num=12")
lcdm_const_only_pp.check_evidence()
print("CPL constrained parameters only block num=12")
cpl_const_only_pp.check_evidence()
print("LCDM all sampled parameters block num=12")
lcdm_all_pp.check_evidence()
print("CPL all sampled parameters block num=12")
cpl_all_pp.check_evidence()
# Out:
# LCDM constrained parameters only block num=12
# === Checking Reliability of Evidence ===
# ln kurtosis: 1.1454 (>>1 implies evidence may be unreliable)
# CPL constrained parameters only block num=12
# === Checking Reliability of Evidence ===
# ln kurtosis: 0.7914 (>>1 implies evidence may be unreliable)
# LCDM all sampled parameters block num=12
# === Checking Reliability of Evidence ===
# ln kurtosis: 0.4776 (>>1 implies evidence may be unreliable)
# CPL all sampled parameters block num=12
# === Checking Reliability of Evidence ===
# ln kurtosis: 0.7514 (>>1 implies evidence may be unreliable)

# %%
# block_num variants for harmonic (BAO+SNe) — fully reinitialise and retrain
harm_const_only_blocks_pp = {12: harm_const_only_pp}
harm_all_blocks_pp = {12: harm_all_pp}
hmZ_lcdm_const_pp = {12: lcdm_const_only_pp.get_hm_evidence()}
hmZ_cpl_const_pp = {12: cpl_const_only_pp.get_hm_evidence()}
hmZ_lcdm_all_pp = {12: lcdm_all_pp.get_hm_evidence()}
hmZ_cpl_all_pp = {12: cpl_all_pp.get_hm_evidence()}

lcdm_root_bs = "../lcdm_chains/PP+DESI"
cpl_root_bs = "../cpl_chains/PP+DESI"

for bn in [8, 24]:
    # constrained-only
    a = make_and_train(lcdm_root_bs, lcdm_cosmo_params, block_num=bn, burnin=0.3)
    b = make_and_train(cpl_root_bs, cpl_cosmo_params, block_num=bn, burnin=0.3)
    harm_const_only_blocks_pp[bn] = a.get_LHME_bayes_factor(b)
    hmZ_lcdm_const_pp[bn] = a.get_hm_evidence()
    hmZ_cpl_const_pp[bn] = b.get_hm_evidence()
    print(f"LCDM constrained parameters only block num={bn}")
    a.check_evidence()
    print(f"CPL constrained parameters only block num={bn}")
    b.check_evidence()

    # constrained + prior-dominated
    a = make_and_train(
        lcdm_root_bs, lcdm_cosmo_params + prior_params, block_num=bn, burnin=0.3
    )
    b = make_and_train(
        cpl_root_bs, cpl_cosmo_params + prior_params, block_num=bn, burnin=0.3
    )
    harm_all_blocks_pp[bn] = a.get_LHME_bayes_factor(b)
    hmZ_lcdm_all_pp[bn] = a.get_hm_evidence()
    hmZ_cpl_all_pp[bn] = b.get_hm_evidence()
    print(f"LCDM all sampled parameters block num={bn}")
    a.check_evidence()
    print(f"CPL all sampled parameters block num={bn}")
    b.check_evidence()
# Out:
# LCDM constrained parameters only block num=8
# === Checking Reliability of Evidence ===
# ln kurtosis: 0.2154 (>>1 implies evidence may be unreliable)
# CPL constrained parameters only block num=8
# === Checking Reliability of Evidence ===
# ln kurtosis: 0.3573 (>>1 implies evidence may be unreliable)
# LCDM all sampled parameters block num=8
# === Checking Reliability of Evidence ===
# ln kurtosis: 0.4282 (>>1 implies evidence may be unreliable)
# CPL all sampled parameters block num=8
# === Checking Reliability of Evidence ===
# ln kurtosis: 0.1102 (>>1 implies evidence may be unreliable)
# LCDM constrained parameters only block num=24
# === Checking Reliability of Evidence ===
# ln kurtosis: 0.5513 (>>1 implies evidence may be unreliable)
# CPL constrained parameters only block num=24
# === Checking Reliability of Evidence ===
# ln kurtosis: 0.8634 (>>1 implies evidence may be unreliable)
# LCDM all sampled parameters block num=24
# === Checking Reliability of Evidence ===
# ...

# %%
# plotting Bayes factor and individual evidences (BAO+SNe)
x_labels_bs = ["Constrained only", "All parameters"]
x_pos_bs = np.array([0, 1])

fig, axes = plt.subplots(1, 2, figsize=(14, 6))

block_nums = [8, 12, 24]
block_offsets = {8: -0.18, 12: 0.0, 24: 0.18}
block_colors = {8: "tab:cyan", 12: "blue", 24: "navy"}
# --- Bayes factor ---
ax = axes[0]
ax.axhline(-2.77, color="black", linestyle=":", label="polyChord")
ax.axhspan(-2.77 - 0.12, -2.77 + 0.12, color="green", alpha=0.15)
ax.plot(
    x_pos_bs,
    [mce_const_only_pp, mce_all_pp],
    "s",
    color="red",
    label="MCE",
    markersize=9,
)
for bn in block_nums:
    means = [harm_const_only_blocks_pp[bn][0], harm_all_blocks_pp[bn][0]]
    lower = [harm_const_only_blocks_pp[bn][1], harm_all_blocks_pp[bn][1]]
    upper = [harm_const_only_blocks_pp[bn][2], harm_all_blocks_pp[bn][2]]
    ax.errorbar(
        x_pos_bs + block_offsets[bn],
        means,
        yerr=[lower, upper],
        fmt="o",
        color=block_colors[bn],
        capsize=5,
        label=f"LHME ({bn})",
        markersize=7,
    )

ax.set_xticks(x_pos_bs)
ax.set_xticklabels(x_labels_bs)
ax.set_ylabel(r"$\ln\mathcal{Z}_\mathrm{CPL}-\ln\mathcal{Z}_{\Lambda\mathrm{CDM}}$")
ax.set_title("Bayes factor")
ax.set_xlim(-1, 2)
ax.legend(fontsize=8)
ax.grid(axis="y", linestyle="--", alpha=0.7)

# --- Individual evidences ---
ax = axes[1]
# PolyChord from Ong:2026tta
ax.axhline(
    -717.22,
    color="darkgreen",
    linestyle="-",
    label="$\\Lambda\\mathrm{CDM}$: polyChord",
)
ax.axhspan(-717.22 - 0.1, -717.22 + 0.1, color="green", alpha=0.15)

ax.axhline(-719.99, color="darkred", linestyle="-", label="CPL: polyChord")
ax.axhspan(-719.99 - 0.12, -719.99 + 0.12, color="red", alpha=0.15)

for bn in block_nums:
    lcdm_co_lnZ, (lcdm_co_lo, lcdm_co_up) = hmZ_lcdm_const_pp[bn]
    cpl_co_lnZ, (cpl_co_lo, cpl_co_up) = hmZ_cpl_const_pp[bn]
    lcdm_al_lnZ, (lcdm_al_lo, lcdm_al_up) = hmZ_lcdm_all_pp[bn]
    cpl_al_lnZ, (cpl_al_lo, cpl_al_up) = hmZ_cpl_all_pp[bn]
    ax.errorbar(
        x_pos_bs + block_offsets[bn] - 0.05,
        [lcdm_co_lnZ, lcdm_al_lnZ],
        yerr=[[lcdm_co_lo, lcdm_al_lo], [lcdm_co_up, lcdm_al_up]],
        fmt="o",
        color=block_colors[bn],
        capsize=5,
        label=f"$\\Lambda\\mathrm{{CDM}}$: LHME({bn})",
        markersize=7,
    )
    ax.errorbar(
        x_pos_bs + block_offsets[bn] + 0.05,
        [cpl_co_lnZ, cpl_al_lnZ],
        yerr=[[cpl_co_lo, cpl_al_lo], [cpl_co_up, cpl_al_up]],
        fmt="^",
        color=block_colors[bn],
        capsize=5,
        label=f"CPL: LHME({bn})",
        markersize=7,
    )

ax.plot(
    x_pos_bs - 0.05,
    [lcdm_const_only_pp.mcevidence, lcdm_all_pp.mcevidence],
    "o",
    color="red",
    label="$\\Lambda\\mathrm{{CDM}}$: MCE",
    markersize=9,
)
ax.plot(
    x_pos_bs + 0.05,
    [cpl_const_only_pp.mcevidence, cpl_all_pp.mcevidence],
    "^",
    color="red",
    label="CPL: MCE",
    markersize=9,
)
ax.set_xticks(x_pos_bs)
ax.set_xticklabels(x_labels_bs)
ax.set_ylabel(r"$\ln\mathcal{Z}$")
ax.set_title("Bayesian evidence")
ax.set_xlim(-1, 2)
ax.legend(fontsize=7)
ax.grid(axis="y", linestyle="--", alpha=0.7)

fig.suptitle("DESI DR2 + Pantheon+")
plt.tight_layout()
plt.savefig("figures/PP_DESI_evidence.pdf", bbox_inches="tight")
plt.show()
# Out:
# INFO:_mathtext.py._get_glyph():642      Substituting symbol Z from STIXNonUnicode
# INFO:_mathtext.py._get_glyph():642      Substituting symbol Z from STIXNonUnicode
# INFO:_mathtext.py._get_glyph():642      Substituting symbol Z from STIXNonUnicode
# INFO:_mathtext.py._get_glyph():642      Substituting symbol Z from STIXNonUnicode
# INFO:_mathtext.py._get_glyph():642      Substituting symbol Z from STIXNonUnicode
# INFO:_mathtext.py._get_glyph():642      Substituting symbol Z from STIXNonUnicode
# INFO:_mathtext.py._get_glyph():642      Substituting symbol Z from STIXNonUnicode
# INFO:_mathtext.py._get_glyph():642      Substituting symbol Z from STIXNonUnicode

# %%
fig, ax = plt.subplots()

ax.axhline(-2.77, color="black", linestyle=":", label="polyChord")
ax.axhspan(-2.77 - 0.12, -2.77 + 0.12, color="green", alpha=0.15)
ax.plot(
    x_pos_bs,
    [mce_const_only_pp, mce_all_pp],
    "s",
    color="red",
    label="MCE",
    markersize=9,
)
for bn in block_nums:
    means = [harm_const_only_blocks_pp[bn][0], harm_all_blocks_pp[bn][0]]
    lower = [harm_const_only_blocks_pp[bn][1], harm_all_blocks_pp[bn][1]]
    upper = [harm_const_only_blocks_pp[bn][2], harm_all_blocks_pp[bn][2]]
    ax.errorbar(
        x_pos_bs + block_offsets[bn],
        means,
        yerr=[lower, upper],
        fmt="o",
        color=block_colors[bn],
        capsize=5,
        label=f"LHME ({bn})",
        markersize=7,
    )

ax.set_xticks(x_pos_bs)
ax.set_xticklabels(x_labels_bs)
ax.set_ylabel(r"$\ln\mathcal{Z}_\mathrm{CPL}-\ln\mathcal{Z}_{\Lambda\mathrm{CDM}}$")
# ax.set_title("Bayes factor")
ax.set_xlim(-1, 2)
ax.legend(fontsize=8)
ax.grid(axis="y", linestyle="--", alpha=0.7)

plt.savefig("figures/PP_DESI_bf.pdf", bbox_inches="tight")
plt.show()
# Out:
# INFO:_mathtext.py._get_glyph():642      Substituting symbol Z from STIXNonUnicode
# INFO:_mathtext.py._get_glyph():642      Substituting symbol Z from STIXNonUnicode
# INFO:_mathtext.py._get_glyph():642      Substituting symbol Z from STIXNonUnicode
# INFO:_mathtext.py._get_glyph():642      Substituting symbol Z from STIXNonUnicode
